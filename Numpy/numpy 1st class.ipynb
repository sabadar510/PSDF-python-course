# %%
import numpy as np
print(np. __version__ )


arr = np.array([1, 2, 3, 4, 5])

print(arr)
# Out:
# 2.4.2
# [1 2 3 4 5]

# %%
ar= np.array([1,2,3,4,5,6]) # 1d array

print(type(ar))
# Out:
# <class 'numpy.ndarray'>

# %%
ar= np.array([23,56,78])
print(ar[1:])
print(ar[2])
print(ar[1:2])
# Out:
# [56 78]
# 78
# [56]

# %%
sb= np.array(["saba", "rabia", "ayesha", 56, "true"]) 
print(sb.dtype) # checking datatype of array
# Out:
# <U21
# [1. 1. 1. 1. 1.]

# %%
fruits= np.array(["apple", "bananaaaa", "kiwi"])
x=fruits.copy() # original array change ho gi or copy wali array same hi rahy gi
x[1]= "pineapple"
print(fruits)
print(x)
# Out:
# ['apple' 'bananaaaa' 'kiwi']
# ['apple' 'pineapple' 'kiwi']

# %%
number= np.array([23,45,67])
y=number.view() #  aik array ma changes krny sy dosari array b effect ho rahi
number[1]=34 
print(number)
print(y)
onr=np.ones(5) 
print(onr)
# Out:
# [23 34 67]
# [23 34 67]
# [1. 1. 1. 1. 1.]

# %%
rollnumber=np.array([[1,2,3,4],[3,4,5,6]])
print(rollnumber.shape) # tells the shape of array like 1d 2d 3d or multi demension
# Out:
# (2, 4)

# %%
num= np.array([[1,2,3,4],[2,3,5,7]], ndmin=6)
print(num)
# Out:
# [[[[[[1 2 3 4]
#      [2 3 5 7]]]]]]

# %%
num.shape
# Out:
# (1, 1, 1, 1, 2, 4)

# %%
a=np.arange(1,10,2)
print(a)
a.reshape(5,1) #5 rows and 1 column
a.reshape(5,1,1) # 5 block 1 row 1 colum
# Out:
# [1 3 5 7 9]
# array([[[1]],
#
#        [[3]],
#
#        [[5]],
#
#        [[7]],
#
#        [[9]]])
